# %%
import numpy as np
import pandas as pd

# %%
#using df for dataframe where we are saving the whole data
df = pd.read_csv('laptop_data.csv')

# %%
#too see the whole data 
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
#to check no of rows and columns
df.shape
# Out:
# (1303, 12)

# %%
#this means it have 1303 rows and 12 columns

# %%
#now we want to know the type of data is used in this
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# ...

# %%
#now will check how many dublicate data is present in this
df.duplicated().sum()
# Out:
# 0

# %%
 #now will check is there any missing value in the column
df.isnull().sum()
#so there is no missing values as well as duplicate value
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
#now we will do Pre-processing
#will remove GB from RAM , kg from Weight and remove the column of Unnamed
#here we are doing this to make object data-type to int data-type

# %%
df.drop(columns=['Unnamed: 0'],inplace= True)

# %%
df.head()
#so here columns is removed
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Ram']=df['Ram'].str.replace('GB','')
df['Weight']=df['Weight'].str.replace('kg','')

# %%
  df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
#but here we can see our Ram and Weight is still object so first we have to change its data type
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')

# %%
df.info()
#now the data types are chenges
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %% [markdown]
# ## Now will do the Analysis on the price Column

# %%
import seaborn as sns
sns.distplot(df['Price'])
# Out:
# C:\Users\PRIYANSHU SINGH\AppData\Local\Temp\ipykernel_10912\2229499591.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
#In this we found that our data is skewed so, we have to take care of it

# %%
df['Company'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Company'>

# %%
#Trying to find out the Avg Price from each Company laptops
sns.barplot(x=df['Company'],y=df['Price'])
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %%
#But here we are not able to indentify the names of company clearly .
import matplotlib.pyplot as plt

sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind = 'bar')
#here we are finding out how many types of laptop are present in this dataset
# Out:
# <Axes: xlabel='TypeName'>

# %%
#now i will find the avg value of every type of These Laptops
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# ### Now i will analyse the Inches column

# %%
sns.distplot(df['Inches'])
# Out:
# C:\Users\PRIYANSHU SINGH\AppData\Local\Temp\ipykernel_10912\1439577752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %% [markdown]
# ### Its hard to analyse ScreenResolutions feature to make it simple
# #### Find the total no of Value count
# ##### Basically multiple info in this particular Column so, will found the Common Info

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %% [markdown]
# ## Now will Do Feature Engg
# #### In this will make new column

# %%
df['Touschscreen']= df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touschscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832             0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232             0
# ...

# %%
df.sample(5)
# Out:
#      Company  TypeName  Inches                  ScreenResolution  \
# 616     Dell  Notebook    15.6                 Full HD 1920x1080
# 1110      HP  Notebook    13.3  Quad HD+ / Touchscreen 3200x1800
# 781     Asus    Gaming    17.3       IPS Panel Full HD 1920x1080
# 355     Dell  Notebook    15.6                 Full HD 1920x1080
# 1150  Lenovo  Notebook    15.6                          1366x768
#
#                               Cpu  Ram                Memory  \
# 616    Intel Core i5 7200U 2.5GHz    4             128GB SSD
# 1110     Intel Core M 6Y54 1.1GHz    8             256GB SSD
# 781   Intel Core i7 6700HQ 2.6GHz   16  256GB SSD +  1TB HDD
# 355    Intel Core i7 8550U 1.8GHz    8  128GB SSD +  2TB HDD
# 1150   Intel Core i3 6006U 2.0GHz    4               1TB HDD
#
#                           Gpu       OpSys  Weight       Price  Touschscreen
# 616        AMD Radeon R5 M420       Linux    2.18   30316.320             0
# ...

# %%
df['IPS panel']=df['ScreenResolution'].apply(lambda x:1 if 'IPS Panel' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touschscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832             0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232             0
# ...

# %%
df.sample(10)
# Out:
#      Company            TypeName  Inches  \
# 857       HP  2 in 1 Convertible    13.3
# 592     Dell  2 in 1 Convertible    11.6
# 1182    Dell            Notebook    15.6
# 762   Google           Ultrabook    12.3
# 678       LG           Ultrabook    15.6
# 207     Dell           Ultrabook    13.3
# 271     Asus              Gaming    17.3
# 268       HP            Notebook    17.3
# 1259     MSI              Gaming    15.6
# 231       HP            Notebook    15.6
#
#                                    ScreenResolution  \
# 857                 Full HD / Touchscreen 1920x1080
# 592                            Touchscreen 1366x768
# 1182                              Full HD 1920x1080
# 762                           Touchscreen 2400x1600
# 678                     IPS Panel Full HD 1920x1080
# 207   IPS Panel 4K Ultra HD / Touchscreen 3840x2160
# 271                               Full HD 1920x1080
# 268                               Full HD 1920x1080
# ...

# %%
sns.barplot(x = df['IPS panel'], y =df['Price'])
# Out:
# <Axes: xlabel='IPS panel', ylabel='Price'>

# %%
new = df['ScreenResolution'].str.split('x', n=1 , expand = True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touschscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832             0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232             0
# ...

# %% [markdown]
# #### But now we also have to extract only numerical part

# %% [markdown]
# #### we are find the code basically

# %%
df['X_res']=df['X_res'].str.replace(',', '').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touschscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832             0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232             0
# ...

# %%
df['X_res']=df['X_res'].astype('int')
df['Y_res']=df['Y_res'].astype('int')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touschscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832             0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touschscreen      1303 non-null   int64
#  12  IPS panel         1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %% [markdown]
# ### Now will find out the correlation of Price with each column

# %%
# df['Company']=df['Company'].astype('int')
# float("Apple")

# %%
# df['Price'] = pd.to_numeric(df['Price'].str.replace('[\$,]', '', regex=True))

# %%
# corr_matrix = df.corr()

# %%
# columns_to_drop = ['company', 'typename', 'ScreenResolution', 'Cpu', 'Memory', 'Gpu', 'OpSys']
# df = df.drop(columns=columns_to_drop, axis=1)

# %%
# df.corr()['Price']

# %% [markdown]
# #### PPI = (root of (x_res)^2 + root of (y_res)^2)/Inches

# %%
df['ppi']=(((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
# df.corr()['Price']

# %%
df.drop(columns = ['ScreenResolution'],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touschscreen  IPS panel  X_res  Y_res         ppi
# 0   71378.6832             0          1   2560   1600  226.983005
# ...

# %%
df.drop(columns=['Inches', 'X_res', 'Y_res'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touschscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832             0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232             0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000             0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360             0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080             0
#
#    IPS panel         ppi
# 0          1  226.983005
# ...

# %% [markdown]
# #### Now our focus is on CPU

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %% [markdown]
# ### Now I will make 5 category CPU's [Intel core i5,i7,i3,Intel,AMD]
# ### And now i will extra first three Element from them

# %%
df['Cpu Name']=df['Cpu'].apply(lambda x: " ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touschscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832             0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232             0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000             0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360             0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080             0
#
#    IPS panel         ppi       Cpu Name
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i5' or text == 'Intel Core i7' or text =='Intel Core i3':
        return text
    else :
        if text.split()[0] == 'Intel':
            return 'Other Intel processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu Brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touschscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832             0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232             0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000             0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360             0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080             0
#
#    IPS panel         ppi       Cpu Name      Cpu Brand
# ...

# %%
df.sample(10)
# Out:
#       Company     TypeName                                   Cpu  Ram  \
# 772   Toshiba     Notebook            Intel Core i5 6200U 2.3GHz    4
# 1004  Toshiba     Notebook            Intel Core i5 6200U 2.3GHz    4
# 645    Lenovo     Notebook  Intel Celeron Dual Core N3060 1.6GHz    4
# 138    Lenovo     Notebook            Intel Core i5 7200U 2.5GHz    4
# 728      Dell     Notebook            Intel Core i5 7200U 2.5GHz    8
# 1070     Dell     Notebook            Intel Core i3 6100U 2.3GHz    4
# 1277     Acer     Notebook  Intel Celeron Dual Core N3060 1.6GHz    4
# 291      Asus       Gaming           Intel Core i7 7700HQ 2.8GHz    8
# 744    Lenovo  Workstation            Intel Core i7 7600U 2.8GHz   16
# 966      Dell     Notebook            Intel Core i5 7200U 2.5GHz    4
#
#                   Memory                      Gpu       OpSys  Weight  \
# 772            128GB SSD    Intel HD Graphics 520  Windows 10    1.75
# ...

# %%
df['Cpu Brand'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Cpu Brand'>

# %%
sns.barplot(x = df['Cpu Brand'], y =df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.drop(columns=['Cpu','Cpu Name'], inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touschscreen  IPS panel         ppi  \
# 0  macOS    1.37   71378.6832             0          1  226.983005
# 1  macOS    1.34   47895.5232             0          0  127.677940
# 2  No OS    1.86   30636.0000             0          0  141.211998
# 3  macOS    1.83  135195.3360             0          1  220.534624
# 4  macOS    1.37   96095.8080             0          1  226.983005
#
#        Cpu Brand
# 0  Intel Core i5
# 1  Intel Core i5
# 2  Intel Core i5
# 3  Intel Core i7
# ...

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x = df['Ram'], y =df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(float)
df["second"] = df["second"].astype(float)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 27
#      23 df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)
#      25 df['second'] = df['second'].str.replace(r'\D', '')
# ---> 27 df["first"] = df["first"].astype(float)
#      28 df["second"] = df["second"].astype(float)
#      30 df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
#
# File C:\Python311\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...

# %%
df.sample(5)
# Out:
#       Company            TypeName  Ram   Memory                    Gpu  \
# 566      Dell            Notebook    4  500 HDD  Intel HD Graphics 620
# 529      Dell            Notebook    8  256 SSD  Intel HD Graphics 620
# 1144       HP  2 in 1 Convertible    8  256 SSD  Intel HD Graphics 520
# 1013       HP           Ultrabook    8  256 SSD  Intel HD Graphics 520
# 648   Toshiba            Notebook    8  256 SSD  Intel HD Graphics 520
#
#            OpSys  Weight        Price  Touschscreen  IPS panel  ...  \
# 566   Windows 10    1.93   51095.5200             0          0  ...
# 529   Windows 10    1.90   73366.5600             0          0  ...
# 1144  Windows 10    1.48   95850.7200             1          0  ...
# 1013  Windows 10    1.54  100550.5488             0          0  ...
# 648   Windows 10    1.20   64628.6400             0          0  ...
#
#       Layer1Hybrid Layer1Flash_Storage Layer 2HDD  Layer 2SSD  Layer 2Hybrid  \
# ...
